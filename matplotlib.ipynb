# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(0,10,200)

# %%
y=np.sin(x)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("this is the value of x--------->")
plt.ylabel("sin x ------>")
plt.title("Sine graph")
# Out:
# Text(0.5, 1.0, 'Sine graph')

# %%
x1 = np.random.rand(50)
y1 = np.random.rand(50)
plt.scatter(x1,y1)

# %%
x3 = ['a' , 'b','c','d','e']
y3 = np.random.rand(5)
plt.bar(x3,y3)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("bar plot")
# Out:
# Text(0.5, 1.0, 'bar plot')

# %%
plt.barh(x3,y3)
# Out:
# <BarContainer object of 5 artists>

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
plt.show()

# %%
x = [1, 2, 3, 4, 5]

y = [5, 4, 3, 2, 1]

 

plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
